# %%
from instruments.itech import IT8500plus
from instruments.abstract_instruments import ProgrammableLoad

# %%
import pyvisa as pv
pv.ResourceManager().list_resources()
# Out:
# ('USB0::0x2EC7::0x8500::804215011797270205::INSTR', 'ASRL4::INSTR')

# %%
load: IT8500plus
load = IT8500plus.open_serial("COM4")

load2: IT8500plus
load2 = IT8500plus.open_visa("USB0::0x2EC7::0x8500::804215011797270205::INSTR")

# %%
load.mode = ProgrammableLoad.Channel.Mode.cc
